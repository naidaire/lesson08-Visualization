# %%
from IPython.display import HTML

import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

plt.style.use('fivethirtyeight')
# %matplotlib inline

plt.rcParams['figure.figsize'] = (8,6)
plt.rcParams['font.size'] = 14

# %%
df = pd.DataFrame(data=np.random.randn(10,4),
                 columns=['col1', 'col2', 'col3', 'col4'],
                 index=['a','b','c','d','e','f','g','h','i','j'])

# %%
df
# Out:
#        col1      col2      col3      col4
# a -0.176783  1.745529  0.746254  2.328803
# b  1.081983 -0.819153 -0.213942 -0.913661
# c -0.251501 -0.191301 -0.236611  0.226978
# d -0.784139 -0.246827 -0.489166  1.734467
# e  1.967005  0.327476  0.833841  0.576576
# f  2.045933  1.147026 -1.412243  0.002866
# g -1.396830 -0.567993 -0.554237 -0.257110
# h  0.174828  0.598179  0.739476  0.888550
# i  0.405108  0.002468  0.988637 -0.267146
# j -0.027571  1.143012  0.332017  0.893421

# %%
# Read in the Boston housing data.
housing_csv = './datasets/boston_housing_data.csv'
housing = pd.read_csv(housing_csv)

# Read in the drinks data.
drink_cols = ['country', 'beer', 'spirit', 'wine', 'liters_alcohol', 'continent']
drinks_csv = './datasets/drinks.csv'
drinks = pd.read_csv(drinks_csv, header=0, names=drink_cols, na_filter=False)

# Read in the ufo data.
ufo = pd.read_csv('./datasets/ufo.csv')
ufo.loc[:, 'Time'] = pd.to_datetime(ufo.Time)
ufo.loc[:, 'Year'] = ufo.Time.dt.year

# %%
ufo.loc[:,'Year'].value_counts().sort_index()
# Out:
# 1930       2
# 1931       2
# 1933       1
# 1934       1
# 1935       1
# 1936       2
# 1937       2
# 1939       3
# 1941       2
# 1942       3
# 1943       5
# 1944       8
# 1945       9
# 1946       8
# 1947      41
# 1948       9
# 1949      19
# 1950      31
# 1951      21
# 1952      52
# 1953      36
# 1954      55
# 1955      33
# 1956      46
# 1957      78
# 1958      53
# 1959      57
# 1960      67
# 1961      50
# 1962      72
#         ...
# 1985     211
# 1986     186
# 1987     210
# 1988     232
# 1989     247
# 1990     237
# 1991     220
# 1992     245
# 1993     292
# 1994     406
# 1995    1344
# 1996     851
# 1997    1237
# 1998    1743
# 1999    2774
# 2000    2635
# 2001    2925
# 2002    2933
# 2003    3507
# 2004    3850
# 2005    3787
# 2006    3445
# 2007    4058
# 2008    4655
# 2009    4251
# 2010    4154
# 2011    5089
# 2012    7263
# 2013    7003
# 2014    5382
# Name: Year, Length: 82, dtype: int64

# %%
ufo.loc[:,'Year'].value_counts().sort_index().plot()

# %%
drinks.loc[:,'continent'].value_counts().sort_index().plot(kind='barh')

# %%
df.plot()

# %%
df.plot(figsize=(15,8));  #height, width

# %%
df.loc[:,'col1'].plot(color='crimson', figsize=(16,8))

# %%
df.loc[:,['col1', 'col4']].plot(figsize=(15,7), style={'col1':':r', 'col4':'vb'})

# %%
housing.loc[:,['ZN', 'INDUS']].plot(figsize=(12,8), style={'ZN':'g', 'INDUS':'--b'})

# %%
drinks.groupby('continent').mean()
# Out:
#                  beer      spirit        wine  liters_alcohol
# continent
# AF          61.471698   16.339623   16.264151        3.007547
# AS          37.045455   60.840909    9.068182        2.170455
# EU         193.777778  132.555556  142.222222        8.617778
# NA         145.434783  165.739130   24.521739        5.995652
# OC          89.687500   58.437500   35.625000        3.381250
# SA         175.083333  114.750000   62.416667        6.308333

# %%
drinks.groupby('continent').mean().plot(kind="bar")

# %%
drinks.groupby('continent').mean().sort_values('beer').plot(kind='bar')

# %%
drinks.groupby('continent').mean().drop('liters_alcohol', axis=1).plot(kind='bar', stacked=True)
